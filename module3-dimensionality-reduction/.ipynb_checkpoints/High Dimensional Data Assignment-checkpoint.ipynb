# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,2*(np.pi), 0.1)
y = np.sin(x)

plt.plot(x,y)
plt.title('Passes the vertical line test')
plt.show()

# %%
plt.plot(y,x)
plt.title('Does not pass the vertical line test')
plt.show()

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# Because multiple outputs are mapped to the same input. Thus, it is ambigious which output should correspond with the input.

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %% [markdown]
# Relations 2 is the sole function. The graph below illustrates that all other relations fail the vertical line test.

# %%
x1 = [1, 3, 1]
y1 = [2, 2, 3]
plt.plot(x1, y1, color='b')

x1 = [1, 2, 6]
y1 = [3, 3, 7]
plt.plot(x1, y1, color='orange')

x1 = [9, 2, 9]
y1 = [4, 1, 6]
plt.plot(x1, y1, color='r')

x1 = [6, 8, 6]
y1 = [2, 3, 4]
plt.plot(x1, y1, color='pink')

x1 = [2, 2, 2]
y1 = [6, 7, 4]
plt.plot(x1, y1, color='g')

plt.show()

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %% [markdown]
# The first function is mapping of vectors $\mathbb{R}^3$  to $\mathbb{R}^3$ .
#
# The seccond function is a mapping of $\mathbb{R}^4$  to $\mathbb{R}^2$ .

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %% [markdown]
# Yes, it is possible for functions to map from a lower dimensional space to a higher dimensional space, one example is f(x) = (x, x)
#
# h(x1, x2) = (x1+x2, x2-x1, x2x1)
#
# [source](https://www.khanacademy.org/math/linear-algebra/matrix-transformations/linear-transformations/v/a-more-formal-understanding-of-functions)

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %% [markdown]
# Calculated the transformation matrixes by hand on paper. Picture below (also in github repo):
# <center>![Vertical Line Test]('/transformationmatrix.heic')</center>

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
# with transformation matrix
pT = np.array([[1,3],[-1,2]])
ptest = np.array([[2],[1]])
result = np.matmul(pT, ptest)
result
# Out:
# array([[5],
#        [0]])

# %%
# without transformation matrix
result = np.array([[2+3*1],[2*1-2]])
result
# Out:
# array([[5],
#        [0]])

# %%
# with transformation matrix
qT = np.array([[4, 1, 2],
              [-1, 2, 3], 
              [5, 1, -2]])
ptest = np.array([[3],
                 [4],
                 [5]])
result = np.matmul(qT, ptest)
result
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %%
# without transformation matrix
result = np.array([[4*3+4+2*5],
                  [2*4-3+3*5],
                  [5*3-2*5+4]])
result
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.
#
# Eigenvectors are vectors that are not 'knocked off of their span' by a linear transformation. Eigenvectors may be stretched or shrunk by a scalar but do not alter their span.
#
# A eigenvalue is simply the scalar that shrinks or stretches the eigenvector during the linear transformation. The eigenvalue can be positive or negative. A negative eigenvalue indicates that the vector reverses direction (while retaining the same span).

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?
# - **Sparcity:** As dimensions are added to datasets, the data points become more spread out. Given enough dimensions this can cause clusters/relationships to diminish as all datapoints become space somewhat evenly.
# - **Computational Intensive:** Running computational tasks across a dataset with a high number of dimensions inherently takes longer/uses more compute resources than low number of dimensions (assuming the same number of observations).
# - **Gaining an intuition for the space:** High deimensional spaces make it difficult to explore and discover relationships between dimensions. Thus, it increases the importance of intuition and hypothesis testing.

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?
#
# - You should have at least 5 times as many observations as you do parameters
# - Having more observations is almsot always better
# - If the number of parameters is ever equal or greater than the number of observations you are at very grave risk of overfitting

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Load the UCI Machine Learning Repository's [Iris Dataset](https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/d546eaee765268bf2f487608c537c05e22e4b221/iris.csv) and use PCA to isolate the dataset's first and second principal components and plot them on a graph.

# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
url = 'https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/d546eaee765268bf2f487608c537c05e22e4b221/iris.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (150, 5)

# %%
#separating out the features
x = df.drop(columns='species')

#separating out the target
target = df['species']

# %%
from sklearn.preprocessing import StandardScaler

# Standardizing the features
x = StandardScaler().fit_transform(x)
# Out:
#           0         1         2         3 species
# 0 -0.900681  1.032057 -1.341272 -1.312977  setosa
# 1 -1.143017 -0.124958 -1.341272 -1.312977  setosa
# 2 -1.385353  0.337848 -1.398138 -1.312977  setosa
# 3 -1.506521  0.106445 -1.284407 -1.312977  setosa
# 4 -1.021849  1.263460 -1.341272 -1.312977  setosa

# %% [markdown]
# ### Using Sklearn

# %%
pca = PCA(n_components=2)

pca.fit(x)

print('Eigenvectors: \n', pca.components_)

print('Eigenvalues: \n', pca.explained_variance_)

B = pca.transform(x)
print('Projected Data: \n', B[:5])
# Out:
# Eigenvectors:
#  [[ 0.52237162 -0.26335492  0.58125401  0.56561105]
#  [ 0.37231836  0.92555649  0.02109478  0.06541577]]
# Eigenvalues:
#  [2.93035378 0.92740362]
# Projected Data:
#  [[-2.26454173  0.5057039 ]
#  [-2.0864255  -0.65540473]
#  [-2.36795045 -0.31847731]
#  [-2.30419716 -0.57536771]
#  [-2.38877749  0.6747674 ]]

# %%
components = pd.DataFrame(B)
final = pd.concat([components,target], axis=1)
final = final.rename(columns={
    0:'Principal Component 1',
    1:'Principal Component 2'
})
final.head()
# Out:
#    Principal Component 1  Principal Component 2 species
# 0              -2.264542               0.505704  setosa
# 1              -2.086426              -0.655405  setosa
# 2              -2.367950              -0.318477  setosa
# 3              -2.304197              -0.575368  setosa
# 4              -2.388777               0.674767  setosa

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)

targets = ['setosa', 'versicolor', 'virginica']
colors = ['g', 'b', 'y']

for target, color in zip(targets, colors):
    subset = final[ final['species'] == target ]
    ax.scatter(subset['Principal Component 1'],
              subset['Principal Component 2'],
              c=color,
              s=50)
    
ax.legend(targets)
ax.set_xlim(-3,3)
ax.set_ylim(-3,3)
plt.show()

# %% [markdown]
# # Stretch Goal
#
# ## 1) Do NOT work on the stretch goal until you feel like you have a firm grasp of eigenvectors, eigenvalues, and PCA. Prioritize self-study over the stretch goal if you are not comfortable with those topics yet.
#
# ## 2) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# <center>![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)</center>
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
