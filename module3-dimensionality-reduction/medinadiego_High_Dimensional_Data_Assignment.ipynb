# %% [markdown]
# <a href="https://colab.research.google.com/github/medinadiegoeverardo/DS-Unit-1-Sprint-4-Linear-Algebra/blob/master/module3-dimensionality-reduction/medinadiego_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 20, 200)
ax.plot(x, np.sin(x));

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 20, 200)
ax.plot(np.sin(x), x);

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# - One input (vertical line) is leading (to or touching) two different outputs

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %% [markdown]
# - Relation 2 is the only function. The other ones have the same x values and different y values.

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %% [markdown]
# - m = dim for input 3, dim for output is 3 as well
# - n = dim for input 3, dim for output 2

# %%
# in some cases, like with the n function, the mapping takes a set of value points from one dimensionality
# and then maps them to a set of values with a smaller dimensionality

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %% [markdown]
# - I think it is possible, given that the input goes through some process within the function that produces more than one output.
# - One example could be creating a new column (3rd dim) given two other conditions (inputs) from two different columns are satisfied?

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
# linear transformations can be described as the (composition of or) transformations of our basis vectors.

#just to be clear
p_x1 = [1, 0]
p_x2 = [0, 1]

# p_ = np.array([[1*a, 3*b],
#               [2*b, -1*a]])

def for_p(a, b):
  return np.array([[a + 3*b],
                   [2*b - a]])

# %%
np.matmul(input_3mat, T_mat)

# %%
aa = for_p(1, 0)
for_p(1, 0)
# Out:
# array([[ 1],
#        [-1]])

# %%
bb = for_p(0, 1)
for_p(0, 1)
# Out:
# array([[3],
#        [2]])

# %%
np.array([[aa],
          [bb]])

# Now Transposed
# Out:
# array([[[[ 1],
#          [-1]]],
#
#
#        [[[ 3],
#          [ 2]]]])

# %%
abc = np.array([[1, 0],
                [0, 1]])
cba = np.array([[1, -1],
                [3, 2]])

# %%
# need to transpose here
to_trans = np.matmul(abc, cba)
np.matmul(abc, cba)
# Out:
# array([[ 1, -1],
#        [ 3,  2]])

# %%
final_t = to_trans.T
to_trans.T
# Out:
# array([[ 1,  3],
#        [-1,  2]])

# %%
q_x1 = [1, 0, 0]
q_x2 = [0, 1, 0]
q_x3 = [0, 0, 1]

# q_ = np.array([[4*a, 1*b, 2*c],
#               [2*b, -1*a, 3*c],
#               [5*a, -2*c, 1*b]])

def for_q(a, b, c):
  return np.array([[4*a + b + 2*c],
                   [2*b - a + 3*c],
                   [5*a - 2*c + b]])

# %%
q__1 = for_q(1, 0, 0)
for_q(1, 0, 0)
# Out:
# array([[ 4],
#        [-1],
#        [ 5]])

# %%
q__2 = for_q(0, 1, 0)
for_q(0, 1, 0)
# Out:
# array([[1],
#        [2],
#        [1]])

# %%
q__3 = for_q(0, 0, 1)
for_q(0, 0, 1)
# Out:
# array([[ 2],
#        [ 3],
#        [-2]])

# %%
np.array([q__1, q__2, q__3])
# Out:
# array([[[ 4],
#         [-1],
#         [ 5]],
#
#        [[ 1],
#         [ 2],
#         [ 1]],
#
#        [[ 2],
#         [ 3],
#         [-2]]])

# %%
# not sure how to fix T matrix above so I will create one from scratch for next question
# q_together = matmul(q__1, q__2)
# then matmul(q_together, q__3) perhaps

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
p_input = np.array([[2, 5]]) # input to function

# %%
transposed_input_p = p_input.T

# %%
# application of your input matrix to the function (or transformation matrix?)
for_p(2, 5)
# Out:
# array([[17],
#        [ 8]])

# %%
# vector-matrix multiplication output of input and t-matrix
np.matmul(final_t, transposed_input_p)
# Out:
# array([[17],
#        [ 8]])

# %%
input_3mat = np.array([[3, 2, 6]])

# %%
transposed_input = input_3mat.T

# %%
np.matmul(T_mat, transposed_input) # q matrix multiplication output
# Out:
# array([[26],
#        [19],
#        [ 5]])

# %%
for_q(3, 2, 6) # q function input
# Out:
# array([[26],
#        [19],
#        [ 5]])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %% [markdown]
# - The eigenvalue is the 'amount' or the extent to which an eigenvector is scaled when a linear transformation occurs.

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %% [markdown]
# - With higher dimensions, it is a lot harder to make sense of any connections between the variable involved since it seems like just noise (increased redundancy)

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %% [markdown]
# - A ratio of 5:1.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Load the UCI Machine Learning Repository's [Iris Dataset](https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/d546eaee765268bf2f487608c537c05e22e4b221/iris.csv) and use PCA to isolate the dataset's first and second principal components and plot them on a graph.

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/d546eaee765268bf2f487608c537c05e22e4b221/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# petal length and width have the most variance

# %%
from numpy import array
from numpy import mean
from numpy import std
from numpy import cov
from numpy.linalg import eig

# %%
petal_length = df['petal_length']

# %%
#petal_length

# %%
to_dataframe

# %%
petal_width = df['petal_width']

# %%
new_df = pd.DataFrame([df['petal_length'], df['petal_width']]).T

# %%
new_df.head()
# Out:
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
mean(new_df['petal_length'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-d1a4b50644db> in <module>()
# ----> 1 mean(new_df['petal_length'])
#
# TypeError: 'Series' object is not callable

# %%
new_df.describe()
# Out:
#        petal_length  petal_width
# count    150.000000   150.000000
# mean       3.758667     1.198667
# std        1.764420     0.763161
# min        1.000000     0.100000
# 25%        1.600000     0.300000
# 50%        4.350000     1.300000
# 75%        5.100000     1.800000
# max        6.900000     2.500000

# %%
df['petal_length'].mean()
# Out:
# 3.7586666666666693

# %%
centered_data_len
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
#                 ..
# 122            NaN
# 123            NaN
# 124            NaN
# 125            NaN
# 126            NaN
# 127            NaN
# 128            NaN
# 129            NaN
# 130            NaN
# 131            NaN
# 132            NaN
# 133            NaN
# 134            NaN
# 135            NaN
# 136            NaN
# 137            NaN
# ...

# %%
mean
# Out:
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
# calculate the mean of each column
mean_len = df['petal_length'].mean()
mean_width = df['petal_width'].mean()
print("\n Means Length: \n", mean_len)
print("\n Means Width: \n", mean_width)

# center columns by subtracting column means
centered_data_len = new_df['petal_length'] - mean_len
centered_data_wid = new_df['petal_width'] - mean_width
print("\n Centered Data: \n", centered_data)
#print("\n Centered Data Width: \n", centered_data_wid)

# calculate the standard deviation of each column
std_dev_len = std(new_df['petal_length'])
std_dev_wid = std(new_df['petal_width'])

# complete the standardization by dividing by std_dev
standardized_data_len = centered_data_len / std_dev_len
standardized_data_wid = centered_data_wid / std_dev_wid
print("\n Standardized Data: \n", standardized_data_len)
print("\n Standardized Data Width: \n", standardized_data_wid)

# calculate covariance matrix of centered matrix
covariance_matrix = cov(standardized_data_len, standardized_data_wid, rowvar=True)
print("\n Covariance Matrix: \n", covariance_matrix)
# covariance_matrix_wid = cov(standardized_data_wid)
# print("\n Covariance Matrix Width: \n", covariance_matrix_wid)

# # eigendecomposition of covariance matrix
# values, vectors = eig(covariance_matrix)
# print("\n Eigenvectors: \n", vectors)
# #print("\n Eigenvalues Length: \n", values)

values, vectors = eig(covariance_matrix)
print("\n Eigenvectors Width: \n", vectors)
print("\n Eigenvalues Width: \n", values)

# # project data
#len_d = vectors.T.dot(centered_data_len)
#wid_d = vectors.T.dot(centered_data_wid)
#print("\n Projected Data Length: \n", len_d)
#print("\n Projected Data Width: \n", wid_d)
# Out:
#  Means Length:
#  3.7586666666666693
#
#  Means Width:
#  1.1986666666666672
#
#  Centered Data:
#       petal_length  petal_width
# 0       -2.358667    -0.998667
# 1       -2.358667    -0.998667
# 2       -2.458667    -0.998667
# 3       -2.258667    -0.998667
# 4       -2.358667    -0.998667
# 5       -2.058667    -0.798667
# 6       -2.358667    -0.898667
# 7       -2.258667    -0.998667
# 8       -2.358667    -0.998667
# 9       -2.258667    -1.098667
# 10      -2.258667    -0.998667
# 11      -2.158667    -0.998667
# 12      -2.358667    -1.098667
# 13      -2.658667    -1.098667
# 14      -2.558667    -0.998667
# 15      -2.258667    -0.798667
# 16      -2.458667    -0.798667
# 17      -2.358667    -0.898667
# 18      -2.058667    -0.898667
# 19      -2.258667    -0.898667
# 20      -2.058667    -0.998667
# 21      -2.258667    -0.798667
# 22      -2.758667    -0.998667
# 23      -2.058667    -0.698667
# 24      -1.858667    -0.998667
# 25      -2.158667    -0.998667
# ...

# %% [markdown]
# # Stretch Goal
#
# ## 1) Do NOT work on the stretch goal until you feel like you have a firm grasp of eigenvectors, eigenvalues, and PCA. Prioritize self-study over the stretch goal if you are not comfortable with those topics yet.
#
# ## 2) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# <center>![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)</center>
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
