# %% [markdown]
# <a href="https://colab.research.google.com/github/gogosean/DS-Unit-1-Sprint-4-Linear-Algebra/blob/master/Bank_Marketing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/gogosean/gogosean.github.io/master/bank_additional_full_csv.csv')

# %%
df.head(5)
# Out:
#    age        job  marital  ... euribor3m nr_employed      y
# 0   56  housemaid  married  ...     4.857      5191.0  False
# 1   57   services  married  ...     4.857      5191.0  False
# 2   37   services  married  ...     4.857      5191.0  False
# 3   40     admin.  married  ...     4.857      5191.0  False
# 4   56   services  married  ...     4.857      5191.0  False
#
# [5 rows x 21 columns]

# %%
df.columns = [x.upper() for x in df.columns]
df.columns = [x.strip() for x in df.columns]

print(df.columns)
# Out:
# Index(['AGE', 'JOB', 'MARITAL', 'EDUCATION', 'DEFAULT', 'HOUSING', 'LOAN',
#        'CONTACT', 'MONTH', 'DAY_OF_WEEK', 'DURATION', 'CAMPAIGN', 'PDAYS',
#        'PREVIOUS', 'POUTCOME', 'EMP_VAR_RATE', 'CONS_PRICE_IDX',
#        'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED', 'Y'],
#       dtype='object')

# %%
df.columns=['AGE', 'JOB', 'MARITAL', 'EDUCATION', 'DEFAULT', 'HOUSING', 'LOAN', 'CONTACT', 'MONTH', 'DAY_OF_WEEK', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'POUTCOME', 'EMP_VAR_RATE', 'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED', 'Y']

# %%
#df.reset_index(inplace=True)
features = df.columns.values
df.head(5)
#print (df.index.AGE)

print(features)
# Out:
# ['AGE' 'JOB' 'MARITAL' 'EDUCATION' 'DEFAULT' 'HOUSING' 'LOAN' 'CONTACT'
#  'MONTH' 'DAY_OF_WEEK' 'DURATION' 'CAMPAIGN' 'PDAYS' 'PREVIOUS' 'POUTCOME'
#  'EMP_VAR_RATE' 'CONS_PRICE_IDX' 'CONS_CONF_IDX' 'EURIBOR3M' 'NR_EMPLOYED'
#  'Y']

# %%
df.columns.value_counts(dropna=False)
# Out:
# POUTCOME          1
# DAY_OF_WEEK       1
# CONTACT           1
# MARITAL           1
# HOUSING           1
# CONS_PRICE_IDX    1
# MONTH             1
# AGE               1
# JOB               1
# EDUCATION         1
# CONS_CONF_IDX     1
# DEFAULT           1
# CAMPAIGN          1
# EURIBOR3M         1
# Y                 1
# PREVIOUS          1
# LOAN              1
# NR_EMPLOYED       1
# EMP_VAR_RATE      1
# DURATION          1
# PDAYS             1
# dtype: int64

# %%
df2 =pd.get_dummies(df)

# %%
df2.head(5)
# Out:
#    AGE  DURATION  ...  POUTCOME_nonexistent  POUTCOME_success
# 0   56       261  ...                     1                 0
# 1   57       149  ...                     1                 0
# 2   37       226  ...                     1                 0
# 3   40       151  ...                     1                 0
# 4   56       307  ...                     1                 0
#
# [5 rows x 64 columns]

# %%
features = list(df2.columns.values)

print(features)
# Out:
# ['AGE', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'EMP_VAR_RATE', 'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED', 'Y', 'JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid', 'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services', 'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown', 'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single', 'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y', 'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate', 'EDUCATION_professional.course', 'EDUCATION_university.degree', 'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes', 'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no', 'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone', 'MONTH_apr', 'MONTH_aug', 'MONTH_dec', 'MONTH_jul', 'MONTH_jun', 'MONTH_mar', 'MONTH_may', 'MONTH_nov', 'MONTH_oct', 'MONTH_sep', 'DAY_OF_WEEK_fri', 'DAY_OF_WEEK_mon', 'DAY_OF_WEEK_thu', 'DAY_OF_WEEK_tue
# ...

# %%
##### Your Code Here #####
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
import matplotlib.pyplot as plt

plt.matshow(df2.corr())
plt.show()

print(df2.corr())
# Out:
#                            AGE  ...  POUTCOME_success
# AGE                   1.000000  ...          0.035626
# DURATION             -0.000866  ...          0.044876
# CAMPAIGN              0.004594  ...         -0.050893
# PDAYS                -0.034369  ...         -0.950700
# PREVIOUS              0.024365  ...          0.524045
# EMP_VAR_RATE         -0.000371  ...         -0.256886
# CONS_PRICE_IDX        0.000857  ...         -0.077416
# CONS_CONF_IDX         0.129372  ...          0.084824
# EURIBOR3M             0.010767  ...         -0.281022
# NR_EMPLOYED          -0.017725  ...         -0.350613
# Y                     0.030399  ...          0.316269
# JOB_admin.           -0.102584  ...          0.025069
# JOB_blue-collar      -0.024191  ...         -0.061403
# JOB_entrepreneur      0.031213  ...         -0.017238
# JOB_housemaid         0.085403  ...          0.002276
# JOB_management        0.062040  ...         -0.001302
# ...

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr(), fignum=f.number)
#plt.xticks(range(df.shape[1]), df.columns, fontsize=2, rotation=45)
#plt.yticks(range(df.shape[1]), df.columns, fontsize=2)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
df.Y.value_counts(dropna=False)
# Out:
# False    36548
# True      4640
# Name: Y, dtype: int64

# %%
df2['Y']=df2['Y'].astype(str)
df2['Y'] = df2['Y'].str.strip()

# %%
def apply_code(string):
 if (string == "True"):
     return int(1)
 else:
     return int(0)
  
df2['Y_ind_binary'] = df2['Y'].apply(apply_code)


#print(df2['Y_ind_binary'].value_counts)

df2.head(5)


print(type(df2['Y_ind_binary']))

print(df2.columns)
# Out:
# <class 'pandas.core.series.Series'>
# Index(['AGE', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'EMP_VAR_RATE',
#        'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED', 'Y',
#        'JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid',
#        'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services',
#        'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown',
#        'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single',
#        'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y',
#        'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate',
#        'EDUCATION_professional.course', 'EDUCATION_university.degree',
#        'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes',
#        'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no',
#        'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone',
# ...

# %%
plotdf = df2[['AGE', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'EMP_VAR_RATE', 'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED','Y_ind_binary']]

# %%
train = plotdf

headers = list(train.columns.values)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


# Replacing missing ages with median

train["Y_ind_binary"][train["Y_ind_binary"]==1] = "Conversion"
train["Y_ind_binary"][train["Y_ind_binary"]==0] = "Non Conversion"


plt.figure()
sns.pairplot(data=train[headers],
             hue="Y_ind_binary", dropna=True)

plt.savefig("1_seaborn_pair_plot.png")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
#pd.crosstab (df2['Y_ind'], df2[['JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid', 'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services', 'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown', 'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single', 'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y', 'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate', 'EDUCATION_professional.course', 'EDUCATION_university.degree', 'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes', 'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no', 'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone', 'MONTH_apr', 'MONTH_aug', 'MONTH_dec', 'MONTH_jul', 'MONTH_jun', 'MONTH_mar', 'MONTH_may', 'MONTH_nov', 'MONTH_oct', 'MONTH_sep', 'DAY_OF_WEEK_fri', 'DAY_OF_WEEK_mon', 'DAY_OF_WEEK_thu', 'DAY_OF_WEEK_tue', 'DAY_OF_WEEK_wed', 'POUTCOME_failure', 'POUTCOME_nonexistent', 'POUTCOME_success', 'Y_ind']] )

cross_features=['Y','JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid', 'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services', 'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown', 'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single', 'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y', 'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate', 'EDUCATION_professional.course', 'EDUCATION_university.degree', 'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes', 'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no', 'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone', 'MONTH_apr', 'MONTH_aug', 'MONTH_dec', 'MONTH_jul', 'MONTH_jun', 'MONTH_mar', 'MONTH_may', 'MONTH_nov', 'MONTH_oct', 'MONTH_sep', 'DAY_OF_WEEK_fri', 'DAY_OF_WEEK_mon', 'DAY_OF_WEEK_thu', 'DAY_OF_WEEK_tue', 'DAY_OF_WEEK_wed', 'POUTCOME_failure', 'POUTCOME_nonexistent', 'POUTCOME_success', 'Y_ind_binary']

for i in cross_features:
  print(' ')
  print("----"*10)
  print(i)
  print(pd.crosstab (df2['Y'], df2[i], normalize='columns'))
  print("----"*10)
  print(' ')
# Out:
#
# ----------------------------------------
# Y
# Y      False  True
# Y
# False    1.0   0.0
# True     0.0   1.0
# ----------------------------------------
#
#
# ----------------------------------------
# JOB_admin.
# JOB_admin.         0         1
# Y
# False       0.893129  0.870274
# True        0.106871  0.129726
# ----------------------------------------
#
#
# ----------------------------------------
# JOB_blue-collar
# JOB_blue-collar         0         1
# Y
# False            0.874679  0.931057
# True             0.125321  0.068943
# ----------------------------------------
#
#
# ----------------------------------------
# JOB_entrepreneur
# JOB_entrepreneur         0         1
# Y
# False             0.886338  0.914835
# True              0.113662  0.085165
# ----------------------------------------
#
#
# ----------------------------------------
# JOB_housemaid
# JOB_housemaid         0    1
# Y
# False          0.887012  0.9
# True           0.112988  0.1
# ...

# %%
pd.crosstab (df2['Y'], df2['Y_ind_binary'], normalize='columns')
print(type(df2['Y_ind_binary']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import numpy as np
from scipy.stats import chisquare
from scipy.stats import chi2_contingency



def getstats(col):
  observed = pd.crosstab(df2['Y'], df2[col]).values
  #print(observed.shape)
  #print(observed)
  print (' ')
  print("----"*10)
  print('Column:',col)
  chi_squared, p_value, dof, expected = chi2_contingency(observed)

  print(f"Chi-Squared: {chi_squared}")
  print(f"P-value: {p_value}")
  print(f"Degrees of Freedom: {dof}") 
  print("Expected: \n", np.array(expected))
  

for i in cross_features:  
  getstats(i)
# Out:
#
# ----------------------------------------
# Column: Y
# Chi-Squared: 41177.99692695045
# P-value: 0.0
# Degrees of Freedom: 1
# Expected:
#  [[32430.71535399  4117.28464601]
#  [ 4117.28464601   522.71535399]]
#
# ----------------------------------------
# Column: JOB_admin.
# Chi-Squared: 40.44872983599433
# P-value: 2.018436228668527e-10
# Degrees of Freedom: 1
# Expected:
#  [[27300.08177139  9247.91822861]
#  [ 3465.91822861  1174.08177139]]
#
# ----------------------------------------
# Column: JOB_blue-collar
# Chi-Squared: 227.56951474021812
# P-value: 2.0202396474322607e-51
# Degrees of Freedom: 1
# Expected:
#  [[28336.50169952  8211.49830048]
#  [ 3597.49830048  1042.50169952]]
#
# ----------------------------------------
# Column: JOB_entrepreneur
# Chi-Squared: 11.126559452236098
# P-value: 0.0008510029748307552
# Degrees of Freedom: 1
# Expected:
#  [[35256.02447315  1291.97552685]
#  [ 4475.97552685   164.02447315]]
#
# ----------------------------------------
# ...

# %%
import numpy as np
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
import pandas as pd

#data = [{'a': 1, 'b': 2}]
data = []
stats=pd.DataFrame(data)

for col in cross_features:
  observed = pd.crosstab(df2['Y'], df2[col]).values
  #print(observed.shape)
  #print(observed)
  print (' ')
  print("----"*10)
  print('Column:',col)
  chi_squared, p_value, dof, expected = chi2_contingency(observed)

  print(f"Chi-Squared: {chi_squared}")
  print(f"P-value: {p_value}")
  print(f"Degrees of Freedom: {dof}") 
  print("Expected: \n", np.array(expected))
  chi = {chi_squared}
  p= {p_value}
  list_p=list(p)
  #stats= stats.append({'Columns': col,'stat':{p_value}},ignore_index=True)

  stats= stats.append({'Columns': col,'stat':list_p[0]}, ignore_index=True )
#for i in cross_features:  
#  getstats(i)

print(' ')
print(' ')
print(' ')

print((stats.sort_values('stat')))
#df.sort_values('2')
# Out:
#
# ----------------------------------------
# Column: Y
# Chi-Squared: 41177.99692695045
# P-value: 0.0
# Degrees of Freedom: 1
# Expected:
#  [[32430.71535399  4117.28464601]
#  [ 4117.28464601   522.71535399]]
#
# ----------------------------------------
# Column: JOB_admin.
# Chi-Squared: 40.44872983599433
# P-value: 2.018436228668527e-10
# Degrees of Freedom: 1
# Expected:
#  [[27300.08177139  9247.91822861]
#  [ 3465.91822861  1174.08177139]]
#
# ----------------------------------------
# Column: JOB_blue-collar
# Chi-Squared: 227.56951474021812
# P-value: 2.0202396474322607e-51
# Degrees of Freedom: 1
# Expected:
#  [[28336.50169952  8211.49830048]
#  [ 3597.49830048  1042.50169952]]
#
# ----------------------------------------
# Column: JOB_entrepreneur
# Chi-Squared: 11.126559452236098
# P-value: 0.0008510029748307552
# Degrees of Freedom: 1
# Expected:
#  [[35256.02447315  1291.97552685]
#  [ 4475.97552685   164.02447315]]
#
# ----------------------------------------
# ...

# %%
print(type(df2['Y_ind_binary']))
print(type(df2['Y_ind_binary']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
stats_filter = stats['stat']<.10
stats_features= stats[stats_filter == True]

stats_features.head(5)
stats_features_listA =list(stats['Columns'])

stats_features_listB=(['AGE', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'EMP_VAR_RATE', 'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED','Y_ind_binary'])
#df3= df2[stats_features]

#print(stats_features) 

stats_features_listB.extend(stats_features_listA)

print(stats_features_listA)
print(stats_features_listB)

df3=df2[stats_features_listB]

df3.head(5)
# Out:
# ['Y', 'JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid', 'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services', 'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown', 'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single', 'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y', 'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate', 'EDUCATION_professional.course', 'EDUCATION_university.degree', 'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes', 'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no', 'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone', 'MONTH_apr', 'MONTH_aug', 'MONTH_dec', 'MONTH_jul', 'MONTH_jun', 'MONTH_mar', 'MONTH_may', 'MONTH_nov', 'MONTH_oct', 'MONTH_sep', 'DAY_OF_WEEK_fri', 'DAY_OF_WEEK_mon', 'DAY_OF_WEEK_thu', 'DAY_OF_WEEK_tue', 'DAY_OF_WEEK_wed', 'POUTCOME_failure', 'POUTCOME_nonexistent', 'POUTCOME_success', 'Y_ind_binary']
# ...

# %% [markdown]
# MAKE CHARTS CountStatus = pd.value_counts(df['scstatus'

# %%
import pandas as pd

df2['Y'].value_counts()

#counts =pd.value_counts(df3['Y_ind'])
print(type(df2['Y_ind_binary']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

train, test = train_test_split(df2, random_state=0)
train.shape, test.shape

train.head(5)
test.head(5)
# Out:
#        AGE  DURATION  ...  POUTCOME_success  Y_ind_binary
# 15500   39       635  ...                 0             1
# 29034   55       248  ...                 0             0
# 11199   39       207  ...                 0             0
# 22247   56       176  ...                 0             0
# 27180   49       271  ...                 0             0
#
# [5 rows x 65 columns]

# %%
print(type(df2['Y_ind_binary']))
predictions = [0] * len(train)
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df2['Y_ind_binary']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
from sklearn.metrics import accuracy_score

predictions = [0] * len(train)

accuracy_score(train.Y_ind_binary,predictions)
#accuracy_score(train.survived, predictions)
accuracy_score(train.Y_ind_binary, predictions)

#df[cat] = le.fit_transform(df[cat].astype(str))
# Out:
# 0.8872810851056943

# %%
from sklearn.metrics import confusion_matrix

def matrix(y_true, y_pred):
    data = confusion_matrix(y_true, y_pred)
    index = ['Actual 0', 'Actual 1']
    columns = ['Predicted 0', 'Predicted 1']
    return pd.DataFrame(data, index, columns)
                        
matrix(train.Y_ind_binary, predictions)
# Out:
#           Predicted 0  Predicted 1
# Actual 0        27409            0
# Actual 1         3482            0

# %%
from sklearn.metrics import recall_score
recall_score(train.Y_ind_binary, predictions)
# Out:
# 0.0

# %%
#train['Y'] = train.Y == 'True'
#test['Y'] = test.Y== 'True'

#train.Y.values

# %%
features = stats_features_listB.copy()

print(features)
 
#features.remove('AGE')

features.remove('Y')

features.remove('Y_ind_binary')

features.remove('POUTCOME_failure')

features.remove('POUTCOME_success')

features.remove('POUTCOME_nonexistent')
 
print(features)  
  
target = 'Y_ind_binary'

features.remove('Y_ind_binary')



print(len(features))
#, 'POUTCOME_nonexistent', 'POUTCOME_success'])
                
print(features)
# Out:
# ['AGE', 'DURATION', 'CAMPAIGN', 'PDAYS', 'PREVIOUS', 'EMP_VAR_RATE', 'CONS_PRICE_IDX', 'CONS_CONF_IDX', 'EURIBOR3M', 'NR_EMPLOYED', 'Y_ind_binary', 'Y', 'JOB_admin.', 'JOB_blue-collar', 'JOB_entrepreneur', 'JOB_housemaid', 'JOB_management', 'JOB_retired', 'JOB_self-employed', 'JOB_services', 'JOB_student', 'JOB_technician', 'JOB_unemployed', 'JOB_unknown', 'MARITAL_divorced', 'MARITAL_married', 'MARITAL_single', 'MARITAL_unknown', 'EDUCATION_basic.4y', 'EDUCATION_basic.6y', 'EDUCATION_basic.9y', 'EDUCATION_high.school', 'EDUCATION_illiterate', 'EDUCATION_professional.course', 'EDUCATION_university.degree', 'EDUCATION_unknown', 'DEFAULT_no', 'DEFAULT_unknown', 'DEFAULT_yes', 'HOUSING_no', 'HOUSING_unknown', 'HOUSING_yes', 'LOAN_no', 'LOAN_unknown', 'LOAN_yes', 'CONTACT_cellular', 'CONTACT_telephone', 'MONTH_apr', 'MONTH_aug', 'MONTH_dec', 'MONTH_jul', 'MONTH_jun', 'MONTH_mar', 'MONTH_may', 'MONTH_nov', 'MONTH_oct', 'MONTH_sep', 'DAY_OF_WEEK_fri', 'DAY_OF_WEEK_mon', 'DAY_OF_WEEK_thu', 
# ...

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(train[features], train[target])

# Train accuracy
y_true = train[target]
y_pred = model.predict(train[features])
print('Train accuracy:', accuracy_score(y_true, y_pred))

# Test accuracy
y_true = test[target]
y_pred = model.predict(test[features])
print('Test accuracy:', accuracy_score(y_true, y_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Train accuracy: 0.9090026221229485
# Test accuracy: 0.9119160920656502

# %%
import matplotlib.pyplot as plt

pd.Series(model.coef_[0], features).plot.barh(color='gray')
plt.title('Logistic Regression coefficients');

# %%
matrix(y_true, y_pred)
# Out:
#           Predicted 0  Predicted 1
# Actual 0         8907          232
# Actual 1          675          483

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=3)
model.fit(train[features], train[target])

# Train accuracy
y_true = train[target]
y_pred = model.predict(train[features])
print('Train accuracy:', accuracy_score(y_true, y_pred))

# Test accuracy
y_true = test[target]
y_pred = model.predict(test[features])
print('Test accuracy:', accuracy_score(y_true, y_pred))
# Out:
# Train accuracy: 0.907060308827814
# Test accuracy: 0.9110420510828396

# %%
# !pip install graphviz
# !apt-get install graphviz
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_data = export_graphviz(model, out_file=None, feature_names=features, 
                           class_names=['Converted', 'Not-Converted'], 
                           filled=True, impurity=False, rotate=True)
graphviz.Source(dot_data)
